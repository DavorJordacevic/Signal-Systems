# %%
# FURIJEOVA TRANSFORMACIJA

# %%
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt

# %%
 from scipy import signal

# %%
# %matplotlib inline

# %%
t= np.arange(0,2,0.001)

# %%
x=np.sin(np.pi*2*2*t) + np.sin(np.pi*2*7*t)+np.sin(np.pi*2*11*t) # + 0.25*np.random.randn(len(x))

# %%
plt.plot(t,x)

# %%
X=sp.fft(x)

# %%
Fs=1000
f=np.linspace(0,Fs,len(x)+1)

# %%
f=f[:-1]

# %%
n=len(x)

# %%
len(f)
# Out:
# 2000

# %%
plt.stem(f[0:50],np.abs(X[0:50]))
# Out:
# <Container object of 3 artists>

# %%
X
# Out:
# array([ -2.78419118e-13 +0.00000000e+00j,
#          4.74064858e-14 -3.12077994e-13j,
#          2.37828387e-13 +1.25233157e-13j, ...,
#          8.39240807e-14 -4.74842254e-13j,
#          2.59299118e-13 +8.22303201e-13j,   4.74064858e-14 +3.12077994e-13j])

# %%
# Filtriranje signala
# Batervortov filter

# %%
b, a = signal.butter(5,0.01 , btype ='low')
w, h = signal.freqz(b,a)
fNorm = w / sp.pi
f1 = fNorm * (Fs/2)

# %%
plt.plot(f1, sp.absolute(h))
plt.title('Filter')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')

# %%
y = signal.lfilter(b,a,x)
plt.plot(t,y)
